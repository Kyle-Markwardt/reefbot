# %%
# This script gets the video length and caption ids for the videos in the video list

# %%
import os
import json
from dotenv import load_dotenv
import pandas as pd
from google.auth.transport.requests import Request as AuthRequest
from googleapiclient.discovery import build
import httplib2
from pprint import pprint
from datetime import timedelta
import re
import pandas as pd

# Load environment variables from .env file
load_dotenv()

# Access API key
yt_api_key = os.getenv("YOUTUBE_API_KEY")

# %%
# Create a YouTube API client
youtube = build('youtube', 'v3', developerKey=yt_api_key)

# %%
### LOAD ###
try:
    videos_with_captions = pd.read_csv('../resources/video_list/videos_with_details.csv', index_col=0)
    print('Succcessfully loaded videos with captions')
    display(videos_with_captions.head(10))
    display(videos_with_captions.tail(10))
    loaded = videos_with_captions.copy()

except:
    videos_df = pd.read_csv('../resources/video_list/videos.csv', index_col=0)
    print('No file found with caption details. Loaded base videos df')
    display(videos_df.head())
    loaded = videos_df.copy()

if 'video_id' in loaded.columns:
    loaded.set_index('video_id', inplace=True)


### CLEAN ###
# Check for duplicate video IDs
duplicate_indices = loaded.index[loaded.index.duplicated()]

# Print the number of duplicate videos
print("Number of duplicate videos:", len(duplicate_indices))

# Print the titles of the duplicate videos
print("Titles of duplicate videos:")
print(loaded.loc[duplicate_indices, 'title'])

# Drop duplicate rows based on index
loaded = loaded[~loaded.index.duplicated()]

# Print the number of dropped videos
print("Dropped videos:", len(duplicate_indices))
# Out:
# Succcessfully loaded videos with captions
#              playlist                                              title  \
# video_id
# E-aoo7Gl2FQ  52_weeks   How to set up a reef tank  | 52 Weeks of Reefing
# fKEXNIhomGs  52_weeks  Week 1: Our Best Reef Tank Build Yet | 52 Week...
# OxZ_hJjXwj8  52_weeks  Week 2: Unveiling the tank and custom built st...
# z6foHVHg1Rw  52_weeks  Week 3: Sumps - What do they do, and which sho...
# tppr8V13h5U  52_weeks  Week 4: Planning a Safer Tank with Redundancy ...
# q1tAnhIGpgA  52_weeks  Week 5: Plumbing, Overflows, and Return Pumps ...
# 1rER7e7zTxU  52_weeks  Week 6: Wiring Your Reef Tank, Everything You ...
# SMq-vk1mnZw  52_weeks  Week 7: How to Produce the Best Water Possible...
# 8vrSO8WLs_M  52_weeks  Week 8: Tank Temperature. Finding a Way to Tru...
# K1Oc1LYgVbo  52_weeks  Week 9: Why Flow Is Vital for a Successful Ree...
#
#              transcribed   length  \
# video_id
# E-aoo7Gl2FQ        False  0:01:28
# fKEXNIhomGs        False  0:02:51
# OxZ_hJjXwj8        False  0:17:38
# z6foHVHg1Rw        False  0:15:11
# tppr8V13h5U        False  0:17:34
# q1tAnhIGpgA        False  0:19:02
# 1rER7e7zTxU        False  0:09:31
# SMq-vk1mnZw        False  0:19:06
# 8vrSO8WLs_M        False  0:14:53
# K1Oc1LYgVbo        False  0:20:23
#
#                                                     caption_id
# video_id
# E-aoo7Gl2FQ  AUieDaanATJE3B_sY3g0XdT4d529fpUTwWeQoRNi8_RNyM...
# fKEXNIhomGs       AUieDaZUPwzNfRgZ8pkyQVjAyPoKqobPj2n8FaNwOUqe
# OxZ_hJjXwj8       AUieDaaGEEmWfrg14IXf7M_i6ZmxAgaPbdif7ba6YD67
# z6foHVHg1Rw       AUieDaaJ5tS6S0lWQ3n0iLGnQupq2Vc6geBy_kXYiyl5
# tppr8V13h5U       AUieDabkVqpY2TKn0EG-plpyrFZjHJVCdSiOFCDIE2mY
# q1tAnhIGpgA  AUieDabKpBko1hu1AwBcvEfjCvJJbbgDqif98oBvI61f2Q...
# 1rER7e7zTxU  AUieDaYleDoSmw_Pj_Uga3E6GU56wMcU93wtei59boXGdX...
# SMq-vk1mnZw       AUieDaas5UnHEaum_T4A0EAOKGj8afPQUHL_RKz0RMFd
# 8vrSO8WLs_M  AUieDabmlIYchPOYyPPocrtLsU54xg2kzH-cPfXyJ-Sh-r...
# K1Oc1LYgVbo       AUieDabBgd4pbA54hPsDLHsvBmOnJyvmP9TYdLCrHXcv
#               playlist                                              title  \
# video_id
# 3h0vR6ltf-s  nutrients  Nutrients vs Nutrition? A Distinction That Cha...
# YMxx6CAH3KU  nutrients  Ocean vs. Reef Aquarium Parameters: A Nitrate ...
# eRz4kdlBIbY  nutrients  A Magic Ratio? Trailblazing Pest Solutions. Ni...
# qr0Wufsw5fs  nutrients  5:1 or 20:1? Fish Food Nutrient Input. The Sol...
# YsJF2q0pS0U  nutrients  The New Reefer / Mentor Paradox. Reef Tank Sta...
# ZiPJiSKkVqA  nutrients  My Beliefs: Nutrients, 17 Years, and How I App...
# IqLgZDp2Wzo  nutrients  A Fish First Approach to Optimizing Fish Food ...
# lMzrWkBmX4g  nutrients  A Challenge: Three Effective Filters for Organ...
# I7_Rm39aOwc  nutrients  Are Water Changes Worth It? A Hammer Solution ...
# bWMkQ4HdAFQ  nutrients  The REAL Truth Behind Nutrients in Our Reef Ta...
#
#              transcribed length caption_id
# video_id
# 3h0vR6ltf-s        False    NaN        NaN
# YMxx6CAH3KU        False    NaN        NaN
# eRz4kdlBIbY        False    NaN        NaN
# qr0Wufsw5fs        False    NaN        NaN
# YsJF2q0pS0U        False    NaN        NaN
# ZiPJiSKkVqA        False    NaN        NaN
# IqLgZDp2Wzo        False    NaN        NaN
# lMzrWkBmX4g        False    NaN        NaN
# I7_Rm39aOwc        False    NaN        NaN
# bWMkQ4HdAFQ        False    NaN        NaN
# Number of duplicate videos: 1
# Titles of duplicate videos:
# video_id
# 3OmI1WNanjA    Week 10: 17 Questions For Success With Clams i...
# 3OmI1WNanjA    Week 10: 17 Questions For Success With Clams i...
# Name: title, dtype: object
# Dropped videos: 1

# %%
# Function for video details
def get_video_details(video_id):
    details = []

    # Retrieve video details
    request = youtube.videos().list(
        part="snippet,contentDetails",  # Include 'contentDetails' to get video duration
        id=video_id
    )
    
    # Create an HTTP instance
    http = httplib2.Http()
    headers = {'referer': 'https://youtube.com'}

    # Execute the request
    response, content = http.request(request.uri, method=request.method, body=request.body, headers=headers)
    response_data = json.loads(content)

    # Extract video details from the response
    for item in response_data['items']:
        duration_str = item['contentDetails']['duration']  # Duration is provided in ISO 8601 format
        video_length = parse_duration(duration_str)
        details.append({'video_id': video_id, 'length': str(video_length)})

    return details


# Function to parse duration string into timedelta object
def parse_duration(duration_str):
    # Regular expression to extract hours, minutes, and seconds
    pattern = r'PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?'
    match = re.match(pattern, duration_str)
    
    # Extract hours, minutes, and seconds
    hours = int(match.group(1)) if match.group(1) else 0
    minutes = int(match.group(2)) if match.group(2) else 0
    seconds = int(match.group(3)) if match.group(3) else 0
    
    # Create a timedelta object with the parsed hours, minutes, and seconds
    duration = timedelta(hours=hours, minutes=minutes, seconds=seconds)
    
    return duration


# Function for caption ids
def get_caption_ids(video_id):
    captions = []

    # Retrieve captions for the video
    request = youtube.captions().list(
        part="snippet",
        videoId=video_id
    )
    # Create an HTTP instance
    http = httplib2.Http()
    headers = {'referer': 'https://youtube.com'}

    try:
        # Execute the request
        response, content = http.request(request.uri, method=request.method, body=request.body, headers=headers)
        response_data = json.loads(content)
        # pprint(response_data)

        # Extract captions from the response
        for item in response_data['items']:
            caption_id = item['id']
            captions.append({'id': caption_id})
    except Exception as e:
        print(f"An error occurred: {e}")
        print(f"Failed video ID: {video_id}")

    return captions

# %%
### MAIN ###

# Test Frame
test_df = loaded.head(10)

#Set environment variable -- dev is for testing the code against the API in small batches to keep quota usage down
production = True

if production == True:
    df = loaded
    environment = 'production'
elif production == False:
    df = test_df.copy()
    environment = 'test'
else:
    print('Error: please set environment')

print(f'Working DataFrame currently set as: ---{environment.upper()}---')

df = df.loc[:, ~df.columns.str.contains('Unnamed')] # Drop any previously generated index duplicates
df.head()
# Out:
# Working DataFrame currently set as: ---PRODUCTION---
#              playlist                                              title  \
# video_id
# E-aoo7Gl2FQ  52_weeks   How to set up a reef tank  | 52 Weeks of Reefing
# fKEXNIhomGs  52_weeks  Week 1: Our Best Reef Tank Build Yet | 52 Week...
# OxZ_hJjXwj8  52_weeks  Week 2: Unveiling the tank and custom built st...
# z6foHVHg1Rw  52_weeks  Week 3: Sumps - What do they do, and which sho...
# tppr8V13h5U  52_weeks  Week 4: Planning a Safer Tank with Redundancy ...
#
#              transcribed   length  \
# video_id
# E-aoo7Gl2FQ        False  0:01:28
# fKEXNIhomGs        False  0:02:51
# OxZ_hJjXwj8        False  0:17:38
# z6foHVHg1Rw        False  0:15:11
# tppr8V13h5U        False  0:17:34
#
#                                                     caption_id
# video_id
# E-aoo7Gl2FQ  AUieDaanATJE3B_sY3g0XdT4d529fpUTwWeQoRNi8_RNyM...
# fKEXNIhomGs       AUieDaZUPwzNfRgZ8pkyQVjAyPoKqobPj2n8FaNwOUqe
# OxZ_hJjXwj8       AUieDaaGEEmWfrg14IXf7M_i6ZmxAgaPbdif7ba6YD67
# z6foHVHg1Rw       AUieDaaJ5tS6S0lWQ3n0iLGnQupq2Vc6geBy_kXYiyl5
# tppr8V13h5U       AUieDabkVqpY2TKn0EG-plpyrFZjHJVCdSiOFCDIE2mY

# %%
for index, row in df.iterrows():
    if pd.isnull(row['length']) or pd.isnull(row['caption_id']):  # Check if either length or caption_id is null
        video_id = row['video_id']
        
        # Get video details if length is null
        if pd.isnull(row['length']):
            video_details = get_video_details(video_id)
            if video_details:
                video_length = video_details[0]['length']
                df.loc[index, 'length'] = video_length

        # Get captions if caption_id is null
        if pd.isnull(row['caption_id']):
            captions = get_caption_ids(video_id)
            if captions:
                caption_id = captions[0]['id']
                df.loc[index, 'caption_id'] = caption_id
# Out:
# An error occurred: 'items'
# Failed video ID: NWmjpqX8fy8
# An error occurred: 'items'
# Failed video ID: fs0lLsRSblw
# An error occurred: 'items'
# Failed video ID: 4lJZCZXE2yo
# An error occurred: 'items'
# Failed video ID: aM0EEW3ZgUU
# An error occurred: 'items'
# Failed video ID: S5nha40KdlQ
# An error occurred: 'items'
# Failed video ID: -f6rRjsnO7w
# An error occurred: 'items'
# Failed video ID: P9jsNTyeGNk
# An error occurred: 'items'
# Failed video ID: CqWod-IvqVA
# An error occurred: 'items'
# Failed video ID: zfcCxzJVqHg
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 7
#       5 # Get video details if length is null
#       6 if pd.isnull(row['length']):
# ----> 7     video_details = get_video_details(video_id)
#       8     if video_details:
#       9         video_length = video_details[0]['length']
#
# Cell In[61], line 20, in get_video_details(video_id)
#      17 response_data = json.loads(content)
#      19 # Extract video details from the response
# ---> 20 for item in response_data['items']:
#      21     duration_str = item['contentDetails']['duration']  # Duration is provided in ISO 8601 format
#      22     video_length = parse_duration(duration_str)
#
# KeyError: 'items'

# %%
display(df.tail(30))
# Out:
#                playlist                                              title  \
# video_id
# OcxRyucO630  interviews  Will It Change? 6 Things the Industry Can Impr...
# 67nCFUwHgsM  interviews  Better Than Carbon? 10 Tips EVERY Reefer Shoul...
# BPeEf69NFZ0  interviews  Vic’s Top 10 Things the Reefing Hobby Should S...
# xxO6K4yU0eU  interviews  Victor’s 13 Secrets to Running a Successful Co...
# ez96AVbRik8  interviews  Victor’s 8 Coral Coloration Tips to Make Your ...
# O5bgq1jwSfo  interviews     Top 10 Things Victor Wishes EVERY Reefer Knew!
# -f6rRjsnO7w       MACNA  Calcium & Alkalinity Supplementation, Tropic M...
# P9jsNTyeGNk       MACNA  Spawning Scolymia, LPS and Potential for Susta...
# CqWod-IvqVA       MACNA  The Importance of Plankton, Where to Get It & ...
# zfcCxzJVqHg       MACNA  ICP & Additives: How to Correct Your Inadequac...
# JI0wbEiTJa0       MACNA  How Less-Than-Ideal Water Chemistry Affects Yo...
# wBIEz7hfcRE       MACNA  The Hard Reboot of a 20,000 Gallon Reef Tank. ...
# 1xISMopla3c       MACNA  A Brief History of Calcification: Limewater to...
# HhlDvKTrSn0       MACNA  A Growing Trend: Marine Macroalgae Tanks. Denn...
# MgZvST0hrqA       MACNA  Garage-A-Culture! Starting an Aquaculture Comp...
# hf7EkDBIQcQ       MACNA  Proper Planning for an Industrial Sized Reef T...
# u_q2rqEXeCU       MACNA  Controlling Algae in Your Aquarium. Rich Ross ...
# SFcQ1GS8hOg       MACNA  Educating the Next Generation of Professional ...
# oVNLxLolQtU   nutrients  Starving Algae and Pests Until They Die? The U...
# TEAV-4sgajE   nutrients  Coral (Animal) vs. Zooxanthellae (Algae)? Care...
# 3h0vR6ltf-s   nutrients  Nutrients vs Nutrition? A Distinction That Cha...
# YMxx6CAH3KU   nutrients  Ocean vs. Reef Aquarium Parameters: A Nitrate ...
# eRz4kdlBIbY   nutrients  A Magic Ratio? Trailblazing Pest Solutions. Ni...
# qr0Wufsw5fs   nutrients  5:1 or 20:1? Fish Food Nutrient Input. The Sol...
# YsJF2q0pS0U   nutrients  The New Reefer / Mentor Paradox. Reef Tank Sta...
# ZiPJiSKkVqA   nutrients  My Beliefs: Nutrients, 17 Years, and How I App...
# IqLgZDp2Wzo   nutrients  A Fish First Approach to Optimizing Fish Food ...
# lMzrWkBmX4g   nutrients  A Challenge: Three Effective Filters for Organ...
# I7_Rm39aOwc   nutrients  Are Water Changes Worth It? A Hammer Solution ...
# bWMkQ4HdAFQ   nutrients  The REAL Truth Behind Nutrients in Our Reef Ta...
#
#              transcribed   length  \
# video_id
# OcxRyucO630        False  0:36:06
# 67nCFUwHgsM        False  0:42:13
# BPeEf69NFZ0        False  0:26:39
# xxO6K4yU0eU        False  0:27:01
# ez96AVbRik8        False  0:33:30
# O5bgq1jwSfo        False  0:56:33
# -f6rRjsnO7w        False  0:48:06
# P9jsNTyeGNk        False  0:44:34
# CqWod-IvqVA        False  0:56:07
# zfcCxzJVqHg        False  0:41:14
# JI0wbEiTJa0        False      NaN
# wBIEz7hfcRE        False      NaN
# 1xISMopla3c        False      NaN
# HhlDvKTrSn0        False      NaN
# MgZvST0hrqA        False      NaN
# hf7EkDBIQcQ        False      NaN
# u_q2rqEXeCU        False      NaN
# SFcQ1GS8hOg        False      NaN
# oVNLxLolQtU        False      NaN
# TEAV-4sgajE        False      NaN
# 3h0vR6ltf-s        False      NaN
# YMxx6CAH3KU        False      NaN
# eRz4kdlBIbY        False      NaN
# qr0Wufsw5fs        False      NaN
# YsJF2q0pS0U        False      NaN
# ZiPJiSKkVqA        False      NaN
# IqLgZDp2Wzo        False      NaN
# lMzrWkBmX4g        False      NaN
# I7_Rm39aOwc        False      NaN
# bWMkQ4HdAFQ        False      NaN
#
#                                                     caption_id
# video_id
# OcxRyucO630  AUieDaY0nnyGuxNs4aTePTt3ckHk7ZGhqvIk_zPEdu3Yd4...
# 67nCFUwHgsM  AUieDabGhcI-SdnF3twdw7_kuXRe0_3Pb46kZXPfeEIDeo...
# BPeEf69NFZ0  AUieDaax7SIei63ujNRSaSpBXFEFcrEI4xL85WMlUD08Kj...
# xxO6K4yU0eU  AUieDaYThG7TzP6T6r9q6D8UlSpxpa4YoiQ1Ft80O7EH8Z...
# ez96AVbRik8  AUieDaaXij1JOi4oAOdYNV8Ki33WBIfh7ycXkdZVhE6qS9...
# O5bgq1jwSfo  AUieDaYP2dR8wX6XNinl5ya8ZKMkO7iKDHhChOaw2G6iEZ...
# -f6rRjsnO7w                                                NaN
# P9jsNTyeGNk                                                NaN
# CqWod-IvqVA                                                NaN
# zfcCxzJVqHg                                                NaN
# JI0wbEiTJa0                                                NaN
# wBIEz7hfcRE                                                NaN
# 1xISMopla3c                                                NaN
# HhlDvKTrSn0                                                NaN
# MgZvST0hrqA                                                NaN
# hf7EkDBIQcQ                                                NaN
# u_q2rqEXeCU                                                NaN
# SFcQ1GS8hOg                                                NaN
# oVNLxLolQtU                                                NaN
# TEAV-4sgajE                                                NaN
# 3h0vR6ltf-s                                                NaN
# YMxx6CAH3KU                                                NaN
# eRz4kdlBIbY                                                NaN
# qr0Wufsw5fs                                                NaN
# YsJF2q0pS0U                                                NaN
# ZiPJiSKkVqA                                                NaN
# IqLgZDp2Wzo                                                NaN
# lMzrWkBmX4g                                                NaN
# I7_Rm39aOwc                                                NaN
# bWMkQ4HdAFQ                                                NaN

# %%
null_length = df['length'].isnull().value_counts()
print(null_length)
null_caption = df['caption_id'].isnull().value_counts()
print(null_caption)
# Out:
# length
# False    249
# True      20
# Name: count, dtype: int64
# caption_id
# False    240
# True      29
# Name: count, dtype: int64

# %%
complete = df[df['length'].notnull() & df['caption_id'].notnull()]
display(complete)

stragglers = df[df['length'].isnull() | df['caption_id'].isnull()]
display(stragglers)
# Out:
#                playlist                                              title  \
# video_id
# E-aoo7Gl2FQ    52_weeks   How to set up a reef tank  | 52 Weeks of Reefing
# fKEXNIhomGs    52_weeks  Week 1: Our Best Reef Tank Build Yet | 52 Week...
# OxZ_hJjXwj8    52_weeks  Week 2: Unveiling the tank and custom built st...
# z6foHVHg1Rw    52_weeks  Week 3: Sumps - What do they do, and which sho...
# tppr8V13h5U    52_weeks  Week 4: Planning a Safer Tank with Redundancy ...
# ...                 ...                                                ...
# 67nCFUwHgsM  interviews  Better Than Carbon? 10 Tips EVERY Reefer Shoul...
# BPeEf69NFZ0  interviews  Vic’s Top 10 Things the Reefing Hobby Should S...
# xxO6K4yU0eU  interviews  Victor’s 13 Secrets to Running a Successful Co...
# ez96AVbRik8  interviews  Victor’s 8 Coral Coloration Tips to Make Your ...
# O5bgq1jwSfo  interviews     Top 10 Things Victor Wishes EVERY Reefer Knew!
#
#              transcribed   length  \
# video_id
# E-aoo7Gl2FQ        False  0:01:28
# fKEXNIhomGs        False  0:02:51
# OxZ_hJjXwj8        False  0:17:38
# z6foHVHg1Rw        False  0:15:11
# tppr8V13h5U        False  0:17:34
# ...                  ...      ...
# 67nCFUwHgsM        False  0:42:13
# BPeEf69NFZ0        False  0:26:39
# xxO6K4yU0eU        False  0:27:01
# ez96AVbRik8        False  0:33:30
# O5bgq1jwSfo        False  0:56:33
#
#                                                     caption_id
# video_id
# E-aoo7Gl2FQ  AUieDaanATJE3B_sY3g0XdT4d529fpUTwWeQoRNi8_RNyM...
# fKEXNIhomGs       AUieDaZUPwzNfRgZ8pkyQVjAyPoKqobPj2n8FaNwOUqe
# OxZ_hJjXwj8       AUieDaaGEEmWfrg14IXf7M_i6ZmxAgaPbdif7ba6YD67
# z6foHVHg1Rw       AUieDaaJ5tS6S0lWQ3n0iLGnQupq2Vc6geBy_kXYiyl5
# tppr8V13h5U       AUieDabkVqpY2TKn0EG-plpyrFZjHJVCdSiOFCDIE2mY
# ...                                                        ...
# 67nCFUwHgsM  AUieDabGhcI-SdnF3twdw7_kuXRe0_3Pb46kZXPfeEIDeo...
# BPeEf69NFZ0  AUieDaax7SIei63ujNRSaSpBXFEFcrEI4xL85WMlUD08Kj...
# xxO6K4yU0eU  AUieDaYThG7TzP6T6r9q6D8UlSpxpa4YoiQ1Ft80O7EH8Z...
# ez96AVbRik8  AUieDaaXij1JOi4oAOdYNV8Ki33WBIfh7ycXkdZVhE6qS9...
# O5bgq1jwSfo  AUieDaYP2dR8wX6XNinl5ya8ZKMkO7iKDHhChOaw2G6iEZ...
#
# [240 rows x 5 columns]
#               playlist                                              title  \
# video_id
# NWmjpqX8fy8   52_weeks  Update 4: Changing over to the Triton Method. ...
# fs0lLsRSblw   52_weeks  The BRS160 Screensaver: 12hrs of Relaxation Wi...
# 4lJZCZXE2yo     52_FAQ  PAR meter rental: Setting your reef tank LED l...
# aM0EEW3ZgUU     52_FAQ  How to change from 2 part dosing to a Calcium ...
# S5nha40KdlQ    11_days  Carbon for Sure... GFO Sometimes... Carbon Dos...
# -f6rRjsnO7w      MACNA  Calcium & Alkalinity Supplementation, Tropic M...
# P9jsNTyeGNk      MACNA  Spawning Scolymia, LPS and Potential for Susta...
# CqWod-IvqVA      MACNA  The Importance of Plankton, Where to Get It & ...
# zfcCxzJVqHg      MACNA  ICP & Additives: How to Correct Your Inadequac...
# JI0wbEiTJa0      MACNA  How Less-Than-Ideal Water Chemistry Affects Yo...
# wBIEz7hfcRE      MACNA  The Hard Reboot of a 20,000 Gallon Reef Tank. ...
# 1xISMopla3c      MACNA  A Brief History of Calcification: Limewater to...
# HhlDvKTrSn0      MACNA  A Growing Trend: Marine Macroalgae Tanks. Denn...
# MgZvST0hrqA      MACNA  Garage-A-Culture! Starting an Aquaculture Comp...
# hf7EkDBIQcQ      MACNA  Proper Planning for an Industrial Sized Reef T...
# u_q2rqEXeCU      MACNA  Controlling Algae in Your Aquarium. Rich Ross ...
# SFcQ1GS8hOg      MACNA  Educating the Next Generation of Professional ...
# oVNLxLolQtU  nutrients  Starving Algae and Pests Until They Die? The U...
# TEAV-4sgajE  nutrients  Coral (Animal) vs. Zooxanthellae (Algae)? Care...
# 3h0vR6ltf-s  nutrients  Nutrients vs Nutrition? A Distinction That Cha...
# YMxx6CAH3KU  nutrients  Ocean vs. Reef Aquarium Parameters: A Nitrate ...
# eRz4kdlBIbY  nutrients  A Magic Ratio? Trailblazing Pest Solutions. Ni...
# qr0Wufsw5fs  nutrients  5:1 or 20:1? Fish Food Nutrient Input. The Sol...
# YsJF2q0pS0U  nutrients  The New Reefer / Mentor Paradox. Reef Tank Sta...
# ZiPJiSKkVqA  nutrients  My Beliefs: Nutrients, 17 Years, and How I App...
# IqLgZDp2Wzo  nutrients  A Fish First Approach to Optimizing Fish Food ...
# lMzrWkBmX4g  nutrients  A Challenge: Three Effective Filters for Organ...
# I7_Rm39aOwc  nutrients  Are Water Changes Worth It? A Hammer Solution ...
# bWMkQ4HdAFQ  nutrients  The REAL Truth Behind Nutrients in Our Reef Ta...
#
#              transcribed    length caption_id
# video_id
# NWmjpqX8fy8        False   0:12:24        NaN
# fs0lLsRSblw        False  11:54:21        NaN
# 4lJZCZXE2yo        False   0:02:20        NaN
# aM0EEW3ZgUU        False   0:06:52        NaN
# S5nha40KdlQ        False   0:33:55        NaN
# -f6rRjsnO7w        False   0:48:06        NaN
# P9jsNTyeGNk        False   0:44:34        NaN
# CqWod-IvqVA        False   0:56:07        NaN
# zfcCxzJVqHg        False   0:41:14        NaN
# JI0wbEiTJa0        False       NaN        NaN
# wBIEz7hfcRE        False       NaN        NaN
# 1xISMopla3c        False       NaN        NaN
# HhlDvKTrSn0        False       NaN        NaN
# MgZvST0hrqA        False       NaN        NaN
# hf7EkDBIQcQ        False       NaN        NaN
# u_q2rqEXeCU        False       NaN        NaN
# SFcQ1GS8hOg        False       NaN        NaN
# oVNLxLolQtU        False       NaN        NaN
# TEAV-4sgajE        False       NaN        NaN
# 3h0vR6ltf-s        False       NaN        NaN
# YMxx6CAH3KU        False       NaN        NaN
# eRz4kdlBIbY        False       NaN        NaN
# qr0Wufsw5fs        False       NaN        NaN
# YsJF2q0pS0U        False       NaN        NaN
# ZiPJiSKkVqA        False       NaN        NaN
# IqLgZDp2Wzo        False       NaN        NaN
# lMzrWkBmX4g        False       NaN        NaN
# I7_Rm39aOwc        False       NaN        NaN
# bWMkQ4HdAFQ        False       NaN        NaN

# %%
### Save outputs
df.to_csv('../resources/video_list/videos_with_details.csv') 
stragglers.to_csv('../resources/video_list/incomplete.csv')
complete.to_csv('../resources/video_list/details_complete.csv')
